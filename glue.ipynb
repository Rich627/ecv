# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, functions

# %%
conf = SparkConf().set("spark.jars", "/Users/rich/Desktop/project/jars/spark-excel_2.12-3.5.0_0.20.3.jar")

sc = SparkContext.getOrCreate(conf=conf)
spark = SparkSession(sc)
df = spark.read.format('excel').option("maxRowsInMemory", 20).load("/Users/rich/Desktop/project/Data/Raw Data_To interns_Contacts.xlsx")
# Out:
# 24/03/22 14:24:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/22 14:25:01 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %% [markdown]
# # Account
# #### ID, isDeleted, Name, LastName, RecordTypeID, OwenerID, CreatedData, CreatedByID, LastModifiedDate, LastModifiedById,
# #### SystemModstamp, PersonContactID, IsPersonAccountm PersonMailingPostalCode, PersonMailingCountry, PersonMailingAddress,
# #### PersonMobilePhone, PersonEmail, PersonBirthdatae, Sex__pc, Legacy_Acct_ID__pc, Legacy_crm_uuid__pc,
# #### Pegister_type_pc, Is_Epaper__pc, Is_userful__pc, block_status__pc, register_date__pc, login_date__pc, Legacy_Contact_ID__pc, member_level_id__pc, crm_custid__pc

# %%
df.withColumn

# %%
account = spark.read.parquet("/Users/rich/Desktop/project/-1602246478-2024-03-20T07_31_23")
account.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 account = spark.read.parquet("/Users/rich/Desktop/ecv project/-1602246478-2024-03-20T07_31_23")
#       2 account.show()
#
# File ~/Desktop/project/ecv_env/lib/python3.9/site-packages/pyspark/sql/readwriter.py:544, in DataFrameReader.parquet(self, *paths, **options)
#     533 int96RebaseMode = options.get("int96RebaseMode", None)
#     534 self._set_opts(
#     535     mergeSchema=mergeSchema,
#     536     pathGlobFilter=pathGlobFilter,
#    (...)
#     541     int96RebaseMode=int96RebaseMode,
#     542 )
# --> 544 return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#
# File ~/Desktop/project/ecv_env/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
# ...

# %% [markdown]
# # Contact
# #### Id, IsDelted, AccountIdm IsPersonAccount, LastName, FirstNamem Salutation, Name
# #### Mailingtreet, MailingCity, MailingState, MailingPostalCode, MailingCountry, MailingAddredd, Phone, Fax, MobilePhone
# #### Email, Title, Departmentm AssiantName, LeadSource, Birthdate, OwnerID, CreatedDate, CreateByID, LastModifiedDate
# #### LastModifiedById, SystemMOdstamp, IsEmailBounced, Level__C, Languages__c, Sex__c, Legacy_Acct_ID__c, Fb_uuid__c
# #### Register_type__c, Is_Epaper__c, Is_userful__c, block_status__c, register_date__c, login_date__C, Legact_Contact_ID__c, member_level_id__C, crn_custid__c

# %%
contact = spark.read.parquet("/Users/rich/Desktop/ecv project/-1148892560-2024-03-21T08_54_24")

contact.show()
# Out:
# +------------------+---------+--------------+------------------+---------------+--------+---------+----------+--------------+-----------+---------+----------+---------------+------------+-------------+--------------+--------------------+------------+--------------------+-----------+------------+-----------------+--------------+---------------+----------------+----------------------+-----------------------+---------------+---------------+---------------+---------+--------------+--------------+-----------+--------------------+--------------------+--------------+-------------+-----------------+-------------------+-----------+------------------+-------------------+------------------+-------------------+------------------+-------------------+----------------+-----------------+----------------+--------------+------------------+------------------+----------------+--------------+--------+------+---------------+------------+---------+------------+------+------------------+----------------+---
# ...

# %% [markdown]
# # Product

# %%
product = spark.read.csv("/Users/rich/Desktop/ecv project/-385754291-2024-03-21T06_39_12")

product.show()
# Out:
# +--------------------+-----------------------------+--------------------+------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------------+-----------------+--------------------+-----------------+------------------+--------------------+--------------------+--------------------+--------------------+
# |                 _c0|                          _c1|                 _c2|               _c3|            _c4|                 _c5|                 _c6|                 _c7|                 _c8|                 _c9|         _c10|                _c11|             _c12|             _c13|                _c14|             _c15|              _c16|                _c17|                _c18|                _c19|                _c20|
# ...

# %% [markdown]
# # Order Table
# #### ID, OwnerId, AccountId, EffectiveDate, EndaDate, IsReductinoOrder, Status, PoDate, PoNumber, StatusCode, ORderNumber, TotalAmount, CratedDate, CreatedById, LastModifiedDate,
# #### LastModifiedById, isDeleted, SystemMOdstamp, Sales_Channel_Nam..., legcy_accu_id__c, Sales_Number__c, channel_sale_num__c

# %%
order = spark.read.csv("/Users/rich/Desktop/ecv project/-929743682-2024-03-21T03_00_36")
order.show()
# Out:
# +------------------+------------------+----------+------------------+------------+---------------+-------------+----------+----------------+------+-----------+--------------------+--------------------+--------------------+--------------------+----+-------------+-----------+------------+-----------------+--------------+---------------+----------------+--------------------+--------------+--------------+------------+-------------+------------------+---------------+----------------+-----------------+--------------------+---------------+----+----------+----------------+--------------------+---------------+---------------+-------------+-------------+----------+-----------+-----------+--------------------+------------------+--------------------+------------------+---------+--------------------+--------------+------------------+--------------------+------------------+--------+--------------+--------+--------------------+---------------+-------------------+
# ...

# %%
account.describe().show()
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# ...

# %%
import pyspark.sql.functions as funcs

df.groupBy(df.columns).count().where(funcs.col('count') > 1).select(funcs.sum('count')).show()
# Out:
# +----------+
# |sum(count)|
# +----------+
# |      NULL|
# +----------+
# 24/03/22 09:37:52 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
# df.dropna()

# %%
df.show()

# %%
# from pyspark.ml.feature import Imputer


# imputer = Imputer(intputCols=).setStrategy("mean")

# %%
df.createOrReplaceTempView('table')

# %%
# spark.sql(
#     """
#         SELECT Name from table 
#             GROUP BY PersonMailingStreet
            
#     """
# ).show()

# %%
# s3 = boto3.client('s3')
# BUCKET_NAME = 'ecv-salsesforce-to-s3'
# PATH = 'Account/schemaVersion_1'

# spark = SparkSession.builder.appName("Read Parquet from S3").getOrCreate()


# df = spark.read.parquet(f"s3://{BUCKET_NAME}/{PATH}/PersonMailingCity=台中市/PersonMailingStreet=大甲區/-1006547190-2024-03-20T06:30:39")

# %%
#Z score

# from pyspark.sql.functions import *
# column_subset = dataframe.columns
# for col in column_subset:
#     if dataframe.select(col).dtypes[0][1]=="string":
#         pass
#     else:
#         mean = dataframe.select(mean(col)).collect()[0][0]
#         stddev = dataframe.select(stddev(col)).collect()[0][0]
#         upper_limit = mean + (3*stddev)
#         lower_limit = mean - (3*stddev)
#         dataframe = dataframe.filter((dataframe[col]<lower_limit) |      (dataframe[col]>upper_limit))
# dataframe.show()

# from pyspark.sql.functions import *
# column_subset = dataframe.columns
# for col in column_subset:
#     if dataframe.select(col).dtypes[0][1]=="string":
#         pass
#     else:
#         mean = dataframe.select(mean(col)).collect()[0][0]
#         stddev = dataframe.select(stddev(col)).collect()[0][0]
#         upper_limit = mean + (3*stddev)
#         lower_limit = mean - (3*stddev)
#         dataframe = dataframe.filter((dataframe[col]>lower_limit) & (dataframe[col]<upper_limit))
# dataframe.show()

# %%
# for col_ in dataframe.columns:
#     if dataframe.select(col_).dtypes[0][1]=="string":
#         pass
#     else:
#         q1,q3 = dataframe.approxQuantile(col_,[0.25, 0.75],0) 
#         IQR = q3 - q1
#         lower_bound = q1 - (1.5*IQR)
#         upper_bound = q3 + (1.5*IQR)
#         dataframe = dataframe.filter((dataframe[col]>lower_bound) & (dataframe[col]<upper_bound))
# dataframe.show()
