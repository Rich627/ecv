# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, functions
import pandas as pd
import pyspark
import boto3

# %%
spark = SparkSession.builder.appName("Read Parquet from S3").getOrCreate()

s3 = boto3.client('s3')
BUCKET_NAME = 'ecv-salsesforce-to-s3'
BASE_PATH = 'Account-NO-PARTITION/schemaVersion1/-1602246478-2024-03-20T07:31:23.parquet'


df = spark.read.parquet("/Users/rich/Desktop/ecv project/-1602246478-2024-03-20T07_31_23")

df.show()
# Out:
# 24/03/20 15:49:09 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# ...

# %%
df2 = spark.read.parquet("/Users/rich/Desktop/ecv project/-1006547190-2024-03-20T06_30_39")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df2 = spark.read.parquet("/Users/rich/Desktop/ecv project/-1006547190-2024-03-20T06_30_39")
#
# File ~/miniconda3/envs/ecv/lib/python3.10/site-packages/pyspark/sql/readwriter.py:544, in DataFrameReader.parquet(self, *paths, **options)
#     533 int96RebaseMode = options.get("int96RebaseMode", None)
#     534 self._set_opts(
#     535     mergeSchema=mergeSchema,
#     536     pathGlobFilter=pathGlobFilter,
#    (...)
#     541     int96RebaseMode=int96RebaseMode,
#     542 )
# --> 544 return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#
# File ~/miniconda3/envs/ecv/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
# ...
